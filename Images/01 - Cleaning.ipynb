# %% [markdown]
# # Imports

# %% [markdown]
# https://data.cityofchicago.org/Transportation/Traffic-Crashes-Crashes/85ca-t3if

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

import seaborn as sns

pd.set_option('display.max_columns', None)

# %% [markdown]
# # Functions

# %% [markdown]
# ## Clean column names

# %%
def clean_col_names(df, char=None):
    if char:
        for ch in char:
            df.columns = df.columns.str.replace(ch, '').str.lower()
            return df.columns
    else:
        df.columns = df.columns.str.lower()
        return df.columns

# %% [markdown]
# ## missing info

# %%
def missing_info(df):
    missing_info_cols = []
    for col in df.columns:
        if df[col].isna().sum() > 0:
            missing_info_cols.append(col)
        else:
            continue
    for cl in missing_info_cols:
        print(cl, df[cl].value_counts(dropna=False), "\n\n")

# %%
def remove_unknowns(data):
    categorical_feature_mask = data.dtypes==object
    categorical_cols = data.columns[categorical_feature_mask].tolist()
    categorical_cols.remove('prim_contributory_cause')

    mult_unique = []
    for col in categorical_cols:
        if data[col].nunique() > 2:
            mult_unique.append(col)
        else:
            continue

    unknown = []
    for col in mult_unique:
        if (data[col] == "UNKNOWN").any():
            unknown.append(col)


    indexes = []
    for col in unknown:
        unknows = data.loc[data[col] == "UNKNOWN"].index
        indexes.extend(unknows)
        np.unique(indexes)
    data.drop(index=indexes, inplace=True)

# %% [markdown]
# # Data Cleaning

# %% [markdown]
# ## Loading Datas (changes)

# %%
df = pd.read_csv("Traffic_Crashes_-_Crashes.csv")
clean_col_names(df, ["_I"])
df.rename(columns= {'crash_type':"injury/tow_or_no", 'first_crash_type':"crash_type"}, inplace=True)

# %%
nodet = df.loc[df["prim_contributory_cause"] == "UNABLE TO DETERMINE"].index
not_determined_df = df.loc[df["prim_contributory_cause"] == "UNABLE TO DETERMINE"]

# %%
df.drop(index=nodet, inplace=True)

# %%
remove_unknowns(df)
remove_unknowns(not_determined_df)
# Out:
# /Users/Alisa/opt/anaconda3/envs/learn-env/lib/python3.6/site-packages/pandas/core/frame.py:4117: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   errors=errors,

# %%
for col in list(df.columns):
    col.value_counts()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-10-4879fb1c3850> in <module>
#       1 for col in list(df.columns):
# ----> 2     col.value_counts()
#
# AttributeError: 'str' object has no attribute 'value_counts'

# %%
df == 'OTHER'
# Out:
#         crash_recordd  rd_no  crash_date_est  crash_date  posted_speed_limit  \
# 0               False  False           False       False               False
# 4               False  False           False       False               False
# 10              False  False           False       False               False
# 13              False  False           False       False               False
# 14              False  False           False       False               False
# ...               ...    ...             ...         ...                 ...
# 395195          False  False           False       False               False
# 395198          False  False           False       False               False
# 395200          False  False           False       False               False
# 395202          False  False           False       False               False
# 395203          False  False           False       False               False
#
#         traffic_control_device  device_condition  weather_condition  \
# 0                        False             False              False
# 4                        False             False              False
# 10                       False             False              False
# 13                       False             False              False
# 14                       False             False              False
# ...                        ...               ...                ...
# 395195                   False             False              False
# 395198                   False             False              False
# 395200                   False             False              False
# 395202                   False             False              False
# 395203                   False             False              False
#
#         lighting_condition  crash_type  trafficway_type  lane_cnt  alignment  \
# 0                    False       False            False     False      False
# 4                    False       False            False     False      False
# 10                   False       False            False     False      False
# 13                   False       False            False     False      False
# 14                   False       False            False     False      False
# ...                    ...         ...              ...       ...        ...
# 395195               False       False            False     False      False
# 395198               False       False            False     False      False
# 395200               False       False            False     False      False
# 395202               False       False            False     False      False
# 395203               False       False            False     False      False
#
#         roadway_surface_cond  road_defect  report_type  injury/tow_or_no  \
# 0                      False        False        False             False
# 4                      False        False        False             False
# 10                     False        False        False             False
# 13                     False        False        False             False
# 14                     False        False        False             False
# ...                      ...          ...          ...               ...
# 395195                 False        False        False             False
# 395198                 False        False        False             False
# 395200                 False        False        False             False
# 395202                 False        False        False             False
# 395203                 False        False        False             False
#
#         intersection_related  not_right_of_way  hit_and_run  damage  \
# 0                      False             False        False   False
# 4                      False             False        False   False
# 10                     False             False        False   False
# 13                     False             False        False   False
# 14                     False             False        False   False
# ...                      ...               ...          ...     ...
# 395195                 False             False        False   False
# 395198                 False             False        False   False
# 395200                 False             False        False   False
# 395202                 False             False        False   False
# 395203                 False             False        False   False
#
#         date_police_notified  prim_contributory_cause  sec_contributory_cause  \
# 0                      False                    False                   False
# 4                      False                    False                   False
# 10                     False                    False                   False
# 13                     False                    False                   False
# 14                     False                    False                   False
# ...                      ...                      ...                     ...
# 395195                 False                    False                   False
# 395198                 False                    False                   False
# 395200                 False                    False                   False
# 395202                 False                    False                   False
# 395203                 False                    False                   False
#
#         street_no  street_direction  street_name  beat_of_occurrence  \
# 0           False             False        False               False
# 4           False             False        False               False
# 10          False             False        False               False
# 13          False             False        False               False
# 14          False             False        False               False
# ...           ...               ...          ...                 ...
# 395195      False             False        False               False
# 395198      False             False        False               False
# 395200      False             False        False               False
# 395202      False             False        False               False
# 395203      False             False        False               False
#
#         photos_taken  statements_taken  dooring  work_zone  work_zone_type  \
# 0              False             False    False      False           False
# 4              False             False    False      False           False
# 10             False             False    False      False           False
# 13             False             False    False      False           False
# 14             False             False    False      False           False
# ...              ...               ...      ...        ...             ...
# 395195         False             False    False      False           False
# 395198         False             False    False      False           False
# 395200         False             False    False      False           False
# 395202         False             False    False      False           False
# 395203         False             False    False      False           False
#
#         workers_present  num_units  most_severenjury  injuries_total  \
# 0                 False      False             False           False
# 4                 False      False             False           False
# 10                False      False             False           False
# 13                False      False             False           False
# 14                False      False             False           False
# ...                 ...        ...               ...             ...
# 395195            False      False             False           False
# 395198            False      False             False           False
# 395200            False      False             False           False
# 395202            False      False             False           False
# 395203            False      False             False           False
#
#         injuries_fatal  injuriesncapacitating  injuries_nonncapacitating  \
# 0                False                  False                      False
# 4                False                  False                      False
# 10               False                  False                      False
# 13               False                  False                      False
# 14               False                  False                      False
# ...                ...                    ...                        ...
# 395195           False                  False                      False
# 395198           False                  False                      False
# 395200           False                  False                      False
# 395202           False                  False                      False
# 395203           False                  False                      False
#
#         injuries_reported_not_evident  injuries_nondication  injuries_unknown  \
# 0                               False                 False             False
# 4                               False                 False             False
# 10                              False                 False             False
# 13                              False                 False             False
# 14                              False                 False             False
# ...                               ...                   ...               ...
# 395195                          False                 False             False
# 395198                          False                 False             False
# 395200                          False                 False             False
# 395202                          False                 False             False
# 395203                          False                 False             False
#
#         crash_hour  crash_day_of_week  crash_month  latitude  longitude  \
# 0            False              False        False     False      False
# 4            False              False        False     False      False
# 10           False              False        False     False      False
# 13           False              False        False     False      False
# 14           False              False        False     False      False
# ...            ...                ...          ...       ...        ...
# 395195       False              False        False     False      False
# 395198       False              False        False     False      False
# 395200       False              False        False     False      False
# 395202       False              False        False     False      False
# 395203       False              False        False     False      False
#
#         location
# 0          False
# 4          False
# 10         False
# 13         False
# 14         False
# ...          ...
# 395195     False
# 395198     False
# 395200     False
# 395202     False
# 395203     False
#
# [213422 rows x 49 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 252089 entries, 0 to 395203
# Data columns (total 49 columns):
# crash_recordd                    252089 non-null object
# rd_no                            249562 non-null object
# crash_date_est                   14208 non-null object
# crash_date                       252089 non-null object
# posted_speed_limit               252089 non-null int64
# traffic_control_device           252089 non-null object
# device_condition                 252089 non-null object
# weather_condition                252089 non-null object
# lighting_condition               252089 non-null object
# crash_type                       252089 non-null object
# trafficway_type                  252089 non-null object
# lane_cnt                         130288 non-null float64
# alignment                        252089 non-null object
# roadway_surface_cond             252089 non-null object
# road_defect                      252089 non-null object
# report_type                      246043 non-null object
# injury/tow_or_no                 252089 non-null object
# intersection_related             65757 non-null object
# not_right_of_way                 11008 non-null object
# hit_and_run                      54759 non-null object
# damage                           252089 non-null object
# date_police_notified             252089 non-null object
# prim_contributory_cause          252089 non-null object
# sec_contributory_cause           252089 non-null object
# street_no                        252089 non-null int64
# street_direction                 252087 non-null object
# street_name                      252089 non-null object
# beat_of_occurrence               252086 non-null float64
# photos_taken                     3662 non-null object
# statements_taken                 6203 non-null object
# dooring                          742 non-null object
# work_zone                        2057 non-null object
# work_zone_type                   1656 non-null object
# workers_present                  496 non-null object
# num_units                        251025 non-null float64
# most_severenjury                 250641 non-null object
# injuries_total                   250647 non-null float64
# injuries_fatal                   250647 non-null float64
# injuriesncapacitating            250647 non-null float64
# injuries_nonncapacitating        250647 non-null float64
# injuries_reported_not_evident    250647 non-null float64
# injuries_nondication             250647 non-null float64
# injuries_unknown                 250647 non-null float64
# crash_hour                       252089 non-null int64
# crash_day_of_week                252089 non-null int64
# crash_month                      252089 non-null int64
# latitude                         250568 non-null float64
# longitude                        250568 non-null float64
# location                         250568 non-null object
# dtypes: float64(12), int64(5), object(32)
# memory usage: 96.2+ MB

# %%
not_determined_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 143115 entries, 1 to 395201
# Data columns (total 49 columns):
# crash_recordd                    143115 non-null object
# rd_no                            141541 non-null object
# crash_date_est                   15052 non-null object
# crash_date                       143115 non-null object
# posted_speed_limit               143115 non-null int64
# traffic_control_device           143115 non-null object
# device_condition                 143115 non-null object
# weather_condition                143115 non-null object
# lighting_condition               143115 non-null object
# crash_type                       143115 non-null object
# trafficway_type                  143115 non-null object
# lane_cnt                         68263 non-null float64
# alignment                        143115 non-null object
# roadway_surface_cond             143115 non-null object
# road_defect                      143115 non-null object
# report_type                      139863 non-null object
# injury/tow_or_no                 143115 non-null object
# intersection_related             22033 non-null object
# not_right_of_way                 7307 non-null object
# hit_and_run                      55171 non-null object
# damage                           143115 non-null object
# date_police_notified             143115 non-null object
# prim_contributory_cause          143115 non-null object
# sec_contributory_cause           143115 non-null object
# street_no                        143115 non-null int64
# street_direction                 143115 non-null object
# street_name                      143114 non-null object
# beat_of_occurrence               143114 non-null float64
# photos_taken                     1331 non-null object
# statements_taken                 1771 non-null object
# dooring                          553 non-null object
# work_zone                        653 non-null object
# work_zone_type                   492 non-null object
# workers_present                  144 non-null object
# num_units                        142582 non-null float64
# most_severenjury                 142142 non-null object
# injuries_total                   142143 non-null float64
# injuries_fatal                   142143 non-null float64
# injuriesncapacitating            142143 non-null float64
# injuries_nonncapacitating        142143 non-null float64
# injuries_reported_not_evident    142143 non-null float64
# injuries_nondication             142143 non-null float64
# injuries_unknown                 142143 non-null float64
# crash_hour                       143115 non-null int64
# crash_day_of_week                143115 non-null int64
# crash_month                      143115 non-null int64
# latitude                         142476 non-null float64
# longitude                        142476 non-null float64
# location                         142476 non-null object
# dtypes: float64(12), int64(5), object(32)
# memory usage: 54.6+ MB

# %% [markdown]
# Everything that I do to **df** i will do to **not_determined_df**

# %% [markdown]
# ## CHECK for missing data or UNKNOWN

# %%
missing_info_cols = []
for col in df.columns:
    if df[col].isna().sum() > 0:
        missing_info_cols.append(col)
    else:
        continue

# %%
for col in missing_info_cols:
    print(col, "\n",  df[col].isna().sum(), "\n")
# Out:
# rd_no
#  2148
#
# crash_date_est
#  202485
#
# lane_cnt
#  101722
#
# report_type
#  5109
#
# intersection_related
#  156353
#
# not_right_of_way
#  204154
#
# hit_and_run
#  169220
#
# street_direction
#  1
#
# beat_of_occurrence
#  2
#
# photos_taken
#  210425
#
# statements_taken
#  208208
#
# dooring
#  212780
#
# work_zone
#  211825
#
# work_zone_type
#  212166
#
# workers_present
#  213013
#
# num_units
#  880
#
# most_severenjury
#  1188
#
# injuries_total
#  1182
#
# injuries_fatal
#  1182
#
# injuriesncapacitating
#  1182
#
# injuries_nonncapacitating
#  1182
#
# injuries_reported_not_evident
#  1182
#
# injuries_nondication
#  1182
#
# injuries_unknown
#  1182
#
# latitude
#  1365
#
# longitude
#  1365
#
# location
#  1365

# %%
df['prim_contributory_cause'].value_counts(dropna=False)
# Out:
# FAILING TO YIELD RIGHT-OF-WAY                                                       38833
# FOLLOWING TOO CLOSELY                                                               37294
# NOT APPLICABLE                                                                      16643
# IMPROPER OVERTAKING/PASSING                                                         15933
# IMPROPER BACKING                                                                    14813
# FAILING TO REDUCE SPEED TO AVOID CRASH                                              13996
# IMPROPER LANE USAGE                                                                 13863
# IMPROPER TURNING/NO SIGNAL                                                          11474
# DRIVING SKILLS/KNOWLEDGE/EXPERIENCE                                                  9867
# DISREGARDING TRAFFIC SIGNALS                                                         5689
# WEATHER                                                                              5471
# OPERATING VEHICLE IN ERRATIC, RECKLESS, CARELESS, NEGLIGENT OR AGGRESSIVE MANNER     3918
# DISREGARDING STOP SIGN                                                               3514
# DISTRACTION - FROM INSIDE VEHICLE                                                    2521
# VISION OBSCURED (SIGNS, TREE LIMBS, BUILDINGS, ETC.)                                 2049
# EQUIPMENT - VEHICLE CONDITION                                                        2041
# PHYSICAL CONDITION OF DRIVER                                                         1963
# UNDER THE INFLUENCE OF ALCOHOL/DRUGS (USE WHEN ARREST IS EFFECTED)                   1742
# EXCEEDING AUTHORIZED SPEED LIMIT                                                     1694
# DISTRACTION - FROM OUTSIDE VEHICLE                                                   1474
# EXCEEDING SAFE SPEED FOR CONDITIONS                                                  1464
# DRIVING ON WRONG SIDE/WRONG WAY                                                      1435
# ROAD ENGINEERING/SURFACE/MARKING DEFECTS                                             1066
# ROAD CONSTRUCTION/MAINTENANCE                                                         860
# DISREGARDING OTHER TRAFFIC SIGNS                                                      702
# EVASIVE ACTION DUE TO ANIMAL, OBJECT, NONMOTORIST                                     602
# DISREGARDING ROAD MARKINGS                                                            495
# CELL PHONE USE OTHER THAN TEXTING                                                     475
# HAD BEEN DRINKING (USE WHEN ARREST IS NOT MADE)                                       365
# ANIMAL                                                                                276
# TURNING RIGHT ON RED                                                                  231
# DISTRACTION - OTHER ELECTRONIC DEVICE (NAVIGATION DEVICE, DVD PLAYER, ETC.)           169
# TEXTING                                                                               155
# DISREGARDING YIELD SIGN                                                               118
# RELATED TO BUS STOP                                                                    86
# BICYCLE ADVANCING LEGALLY ON RED LIGHT                                                 54
# PASSING STOPPED SCHOOL BUS                                                             47
# OBSTRUCTED CROSSWALKS                                                                  19
# MOTORCYCLE ADVANCING LEGALLY ON RED LIGHT                                              11
# Name: prim_contributory_cause, dtype: int64

# %% [markdown]
# There are 143,115 unable to determine
#
# - get rid of them?
#
# Got rid of these above -- will use in future

# %% [markdown]
# Drop (not helpful)
#
# - RD_NO - alot missing; not helpful for model (unique value)
# - LANE_CNT - 19,000 missing; there are really big #; WHERE DID THIS EVEN HAPPEN?
# - CRASH_RECORD_ID
# - crash_date_est
#
#
# Y Or N
#
# - CRASH_DATE_EST_I - alot of missing values(365944); Crash date estimated by desk officer or reporting party (only used in cases where crash is reported at police station days after the crash)
# - REPORT_TYPE - 9298 missing; **CAN BE USED instead of THE ABOVE** ; Administrative report type (at scene, at desk, amended)
#
#
# - INTERSECTION_RELATED_I - alot missing;  **how accident happened**
# - NOT_RIGHT_OF_WAY_I - alot missing;   **how accident happened**
# - HIT_AND_RUN_I - alot missing;  **how accident happened**
# - DOORING - alot missing; **how accident happened**
#
#
# - WORK_ZONE_I - alot missing; **if accident happend on workzone**
# - WORKERS_PRESENT_I - ALOT missing;
#
#
# - PHOTOS TAKEN - ALOT missing; do we really need this column?
# - STATEMENTS_TAKEN_I - alot missing; do we really need this column?
#
#
# EASY TO DEAL WITH
#
# - STREET_DIRECTION - only 2 missing values; DROP MISING VALUES last
# - STREET_NAME - only one missing; DROP MISSING VALUE last
# - BEAT_OF_OCCURANCE - only 4 missing; DROP MISSING VALUE last (the different sections of chicago)
#
#
# - NUM_UNITs - only 1,597 missing; MAYBE DROP MISSING VALUES LAST (# people in accident)
#
#
# - MOST_SEVERE_INJURY - only 2,421 missing DROP AT END
# - INJURIES_TOTAL- only 2414 missing; drop at end
# - INJURIES_FATAL - only 2414 missing; drop at end
# - INJURIES_INCAPACITATING -
# - INJURIES_NON_INCAPACITATING -
# - INJURIES_REPORTED_NOT_EVIDENT -
# - INJURIES_NO_INDICATION -
# - INJURIES_UNKNOWN -
#
#
# - LATITUDE - only 2,160 missing look at end; maybe drop
# - LONGITUDE - only 2,160 missing look at end; maybe drop
# - LOCATIONonly 2,160 missing look at end; maybe drop
#
#
#
# Confused
#
# - WORK_ZONE_TYPE - alot missing; THERE IS UNKNOWN COLUMN;

# %% [markdown]
# ## Columns to drop initially (changes)

# %%
df.head(2)
# Out:
#                                        crash_recordd     rd_no crash_date_est  \
# 0  00027e2894dd2f3fe4ff320a6d332d18e465b5c8ba2e79...  JC201794            NaN
# 4  0006882952e53c291df267014a03b57684383e9ad66d9e...  JC459747            NaN
#
#                crash_date  posted_speed_limit traffic_control_device  \
# 0  03/27/2019 04:20:00 PM                  30            NO CONTROLS
# 4  10/04/2019 12:00:00 PM                  30         TRAFFIC SIGNAL
#
#        device_condition weather_condition lighting_condition crash_type  \
# 0           NO CONTROLS             CLEAR           DAYLIGHT      ANGLE
# 4  FUNCTIONING PROPERLY             CLEAR           DAYLIGHT   REAR END
#
#   trafficway_type  lane_cnt           alignment roadway_surface_cond  \
# 0     NOT DIVIDED       NaN  STRAIGHT AND LEVEL                  DRY
# 4     NOT DIVIDED       NaN  STRAIGHT AND LEVEL                  DRY
#
#   road_defect                 report_type        injury/tow_or_no  \
# 0  NO DEFECTS                    ON SCENE  NO INJURY / DRIVE AWAY
# 4  NO DEFECTS  NOT ON SCENE (DESK REPORT)  NO INJURY / DRIVE AWAY
#
#   intersection_related not_right_of_way hit_and_run         damage  \
# 0                  NaN              NaN         NaN  $501 - $1,500
# 4                    Y              NaN         NaN    OVER $1,500
#
#      date_police_notified        prim_contributory_cause  \
# 0  03/27/2019 04:27:00 PM  FAILING TO YIELD RIGHT-OF-WAY
# 4  10/04/2019 12:35:00 PM          FOLLOWING TOO CLOSELY
#
#        sec_contributory_cause  street_no street_direction     street_name  \
# 0              NOT APPLICABLE       6223                N  CALIFORNIA AVE
# 4  IMPROPER TURNING/NO SIGNAL       2401                S       DAMEN AVE
#
#    beat_of_occurrence photos_taken statements_taken dooring work_zone  \
# 0              2413.0          NaN              NaN     NaN       NaN
# 4              1034.0          NaN              NaN     NaN       NaN
#
#   work_zone_type workers_present  num_units         most_severenjury  \
# 0            NaN             NaN        2.0  NO INDICATION OF INJURY
# 4            NaN             NaN        2.0  NO INDICATION OF INJURY
#
#    injuries_total  injuries_fatal  injuriesncapacitating  \
# 0             0.0             0.0                    0.0
# 4             0.0             0.0                    0.0
#
#    injuries_nonncapacitating  injuries_reported_not_evident  \
# 0                        0.0                            0.0
# 4                        0.0                            0.0
#
#    injuries_nondication  injuries_unknown  crash_hour  crash_day_of_week  \
# 0                   4.0               0.0          16                  4
# 4                   2.0               0.0          12                  6
#
#    crash_month   latitude  longitude                                  location
# 0            3  41.994704 -87.699395  POINT (-87.699395085278 41.994703544264)
# 4           10  41.848490 -87.675599   POINT (-87.67559940405 41.848490427751)

# %%
df[["crash_date_est", "crash_date",  "crash_month","crash_day_of_week",  "crash_hour","report_type"]][:5]
# Out:
#    crash_date_est              crash_date  crash_month  crash_day_of_week  \
# 0             NaN  03/27/2019 04:20:00 PM            3                  4
# 4             NaN  10/04/2019 12:00:00 PM           10                  6
# 6             NaN  08/17/2019 02:00:00 AM            8                  7
# 10            NaN  11/09/2017 08:05:00 PM           11                  5
# 12            NaN  02/10/2019 03:00:00 PM            2                  1
#
#     crash_hour                 report_type
# 0           16                    ON SCENE
# 4           12  NOT ON SCENE (DESK REPORT)
# 6            2  NOT ON SCENE (DESK REPORT)
# 10          20  NOT ON SCENE (DESK REPORT)
# 12          15  NOT ON SCENE (DESK REPORT)

# %%
df["crash_date_est"].value_counts()
# Out:
# Y    12094
# N     2114
# Name: crash_date_est, dtype: int64

# %%
df["report_type"].value_counts()
# Out:
# NOT ON SCENE (DESK REPORT)    139456
# ON SCENE                      106587
# Name: report_type, dtype: int64

# %%
df[["crash_type", "injury/tow_or_no"]][:5]
# Out:
#     crash_type                  injury/tow_or_no
# 0        ANGLE            NO INJURY / DRIVE AWAY
# 4     REAR END            NO INJURY / DRIVE AWAY
# 6   PEDESTRIAN  INJURY AND / OR TOW DUE TO CRASH
# 10    REAR END            NO INJURY / DRIVE AWAY
# 12    REAR END            NO INJURY / DRIVE AWAY

# %%
df['work_zone'].value_counts(dropna=False)
# Out:
# NaN    250032
# Y        1656
# N         401
# Name: work_zone, dtype: int64

# %%
df['work_zone_type'].value_counts(dropna=False)
# Out:
# NaN             250433
# CONSTRUCTION      1176
# UNKNOWN            199
# MAINTENANCE        175
# UTILITY            106
# Name: work_zone_type, dtype: int64

# %% [markdown]
# Drop (not helpful)
#
# - RD_NO - alot missing; not helpful for model (unique value)
# - LANE_CNT - 19,000 missing; there are really big #; WHERE DID THIS EVEN HAPPEN?
# - CRASH_RECORD_ID - a unique number not helpful for regression
# - crash_date_est - using report type instead (no missing values)
# - photos_taken - SOO many missing
# - statement_taken - SO MANY MISSING
#         - should i keep or no? sec_contributory_cause
# -

# %%
df1 = df.drop(columns=['rd_no','lane_cnt','crash_recordd','crash_date_est','photos_taken', 'statements_taken', 'injuries_unknown', 'location'])
not_determined_df = not_determined_df.drop(columns=['rd_no','lane_cnt','crash_recordd','crash_date_est','photos_taken', 'statements_taken', 'injuries_unknown', 'location'])

df1["crash_date"] = df1["crash_date"].astype('datetime64[ns]')
df1['year'] = pd.DatetimeIndex(df1['crash_date']).year

not_determined_df["crash_date"] = not_determined_df["crash_date"].astype('datetime64[ns]')
not_determined_df['year'] = pd.DatetimeIndex(not_determined_df['crash_date']).year

# %%
df1.head(2)
# Out:
#                crash_date  posted_speed_limit traffic_control_device  \
# 0  03/27/2019 04:20:00 PM                  30            NO CONTROLS
# 4  10/04/2019 12:00:00 PM                  30         TRAFFIC SIGNAL
#
#        device_condition weather_condition lighting_condition crash_type  \
# 0           NO CONTROLS             CLEAR           DAYLIGHT      ANGLE
# 4  FUNCTIONING PROPERLY             CLEAR           DAYLIGHT   REAR END
#
#   trafficway_type           alignment roadway_surface_cond road_defect  \
# 0     NOT DIVIDED  STRAIGHT AND LEVEL                  DRY  NO DEFECTS
# 4     NOT DIVIDED  STRAIGHT AND LEVEL                  DRY  NO DEFECTS
#
#                   report_type        injury/tow_or_no intersection_related  \
# 0                    ON SCENE  NO INJURY / DRIVE AWAY                  NaN
# 4  NOT ON SCENE (DESK REPORT)  NO INJURY / DRIVE AWAY                    Y
#
#   not_right_of_way hit_and_run         damage    date_police_notified  \
# 0              NaN         NaN  $501 - $1,500  03/27/2019 04:27:00 PM
# 4              NaN         NaN    OVER $1,500  10/04/2019 12:35:00 PM
#
#          prim_contributory_cause      sec_contributory_cause  street_no  \
# 0  FAILING TO YIELD RIGHT-OF-WAY              NOT APPLICABLE       6223
# 4          FOLLOWING TOO CLOSELY  IMPROPER TURNING/NO SIGNAL       2401
#
#   street_direction     street_name  beat_of_occurrence dooring work_zone  \
# 0                N  CALIFORNIA AVE              2413.0     NaN       NaN
# 4                S       DAMEN AVE              1034.0     NaN       NaN
#
#   work_zone_type workers_present  num_units         most_severenjury  \
# 0            NaN             NaN        2.0  NO INDICATION OF INJURY
# 4            NaN             NaN        2.0  NO INDICATION OF INJURY
#
#    injuries_total  injuries_fatal  injuriesncapacitating  \
# 0             0.0             0.0                    0.0
# 4             0.0             0.0                    0.0
#
#    injuries_nonncapacitating  injuries_reported_not_evident  \
# 0                        0.0                            0.0
# 4                        0.0                            0.0
#
#    injuries_nondication  crash_hour  crash_day_of_week  crash_month  \
# 0                   4.0          16                  4            3
# 4                   2.0          12                  6           10
#
#     latitude  longitude
# 0  41.994704 -87.699395
# 4  41.848490 -87.675599

# %% [markdown]
# ## Explore new df (drop/fill in etc) (changes)

# %%
df1.isna().sum()
# Out:
# crash_date                            0
# posted_speed_limit                    0
# traffic_control_device                0
# device_condition                      0
# weather_condition                     0
# lighting_condition                    0
# crash_type                            0
# trafficway_type                       0
# alignment                             0
# roadway_surface_cond                  0
# road_defect                           0
# report_type                        6046
# injury/tow_or_no                      0
# intersection_related             186332
# not_right_of_way                 241081
# hit_and_run                      197330
# damage                                0
# date_police_notified                  0
# prim_contributory_cause               0
# sec_contributory_cause                0
# street_no                             0
# street_direction                      2
# street_name                           0
# beat_of_occurrence                    3
# dooring                          251347
# work_zone                        250032
# work_zone_type                   250433
# workers_present                  251593
# num_units                          1064
# most_severenjury                   1448
# injuries_total                     1442
# injuries_fatal                     1442
# injuriesncapacitating              1442
# injuries_nonncapacitating          1442
# injuries_reported_not_evident      1442
# injuries_nondication               1442
# crash_hour                            0
# crash_day_of_week                     0
# crash_month                           0
# latitude                           1521
# longitude                          1521
# dtype: int64

# %%
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 252089 entries, 0 to 395203
# Data columns (total 41 columns):
# crash_date                       252089 non-null object
# posted_speed_limit               252089 non-null int64
# traffic_control_device           252089 non-null object
# device_condition                 252089 non-null object
# weather_condition                252089 non-null object
# lighting_condition               252089 non-null object
# crash_type                       252089 non-null object
# trafficway_type                  252089 non-null object
# alignment                        252089 non-null object
# roadway_surface_cond             252089 non-null object
# road_defect                      252089 non-null object
# report_type                      246043 non-null object
# injury/tow_or_no                 252089 non-null object
# intersection_related             65757 non-null object
# not_right_of_way                 11008 non-null object
# hit_and_run                      54759 non-null object
# damage                           252089 non-null object
# date_police_notified             252089 non-null object
# prim_contributory_cause          252089 non-null object
# sec_contributory_cause           252089 non-null object
# street_no                        252089 non-null int64
# street_direction                 252087 non-null object
# street_name                      252089 non-null object
# beat_of_occurrence               252086 non-null float64
# dooring                          742 non-null object
# work_zone                        2057 non-null object
# work_zone_type                   1656 non-null object
# workers_present                  496 non-null object
# num_units                        251025 non-null float64
# most_severenjury                 250641 non-null object
# injuries_total                   250647 non-null float64
# injuries_fatal                   250647 non-null float64
# injuriesncapacitating            250647 non-null float64
# injuries_nonncapacitating        250647 non-null float64
# injuries_reported_not_evident    250647 non-null float64
# injuries_nondication             250647 non-null float64
# crash_hour                       252089 non-null int64
# crash_day_of_week                252089 non-null int64
# crash_month                      252089 non-null int64
# latitude                         250568 non-null float64
# longitude                        250568 non-null float64
# dtypes: float64(10), int64(5), object(26)
# memory usage: 80.8+ MB

# %%
ind = df1['latitude'].isna()

# %%
df1.loc[ind]
# Out:
#                     crash_date  posted_speed_limit traffic_control_device  \
# 35      10/02/2018 06:30:00 PM                  10            NO CONTROLS
# 13255   11/08/2019 01:00:00 AM                  30            NO CONTROLS
# 17814   09/21/2019 07:17:00 PM                  30            NO CONTROLS
# 32501   02/19/2020 10:00:00 AM                  20            NO CONTROLS
# 37193   03/02/2020 08:01:00 PM                  10            NO CONTROLS
# ...                        ...                 ...                    ...
# 393955  07/16/2018 03:09:00 PM                  30            NO CONTROLS
# 394095  12/18/2019 04:09:00 PM                  30            NO CONTROLS
# 394122  06/04/2018 04:40:00 PM                  30            NO CONTROLS
# 394573  04/25/2019 01:30:00 PM                  10            NO CONTROLS
# 394587  01/15/2019 09:00:00 PM                  25            NO CONTROLS
#
#        device_condition weather_condition      lighting_condition  \
# 35          NO CONTROLS             CLEAR                DARKNESS
# 13255       NO CONTROLS             CLEAR                DAYLIGHT
# 17814       NO CONTROLS             CLEAR                DARKNESS
# 32501       NO CONTROLS             CLEAR                DAYLIGHT
# 37193       NO CONTROLS             CLEAR  DARKNESS, LIGHTED ROAD
# ...                 ...               ...                     ...
# 393955      NO CONTROLS             CLEAR                DAYLIGHT
# 394095      NO CONTROLS             CLEAR                DAYLIGHT
# 394122      NO CONTROLS             CLEAR                DAYLIGHT
# 394573      NO CONTROLS             CLEAR                DAYLIGHT
# 394587      NO CONTROLS              RAIN  DARKNESS, LIGHTED ROAD
#
#                       crash_type trafficway_type           alignment  \
# 35          PARKED MOTOR VEHICLE           OTHER  STRAIGHT AND LEVEL
# 13255       PARKED MOTOR VEHICLE     NOT DIVIDED  STRAIGHT AND LEVEL
# 17814               FIXED OBJECT           OTHER  STRAIGHT AND LEVEL
# 32501   SIDESWIPE SAME DIRECTION         ONE-WAY  STRAIGHT AND LEVEL
# 37193       PARKED MOTOR VEHICLE     PARKING LOT  STRAIGHT AND LEVEL
# ...                          ...             ...                 ...
# 393955      PARKED MOTOR VEHICLE         ONE-WAY  STRAIGHT AND LEVEL
# 394095                  REAR END     NOT DIVIDED  STRAIGHT AND LEVEL
# 394122  SIDESWIPE SAME DIRECTION         ONE-WAY  STRAIGHT AND LEVEL
# 394573                PEDESTRIAN     PARKING LOT  STRAIGHT AND LEVEL
# 394587  SIDESWIPE SAME DIRECTION         ONE-WAY  STRAIGHT AND LEVEL
#
#        roadway_surface_cond road_defect                 report_type  \
# 35                      DRY  NO DEFECTS                    ON SCENE
# 13255                   DRY  NO DEFECTS  NOT ON SCENE (DESK REPORT)
# 17814                   DRY  NO DEFECTS                    ON SCENE
# 32501                   DRY  NO DEFECTS                    ON SCENE
# 37193                   DRY  NO DEFECTS                    ON SCENE
# ...                     ...         ...                         ...
# 393955                  DRY  NO DEFECTS                    ON SCENE
# 394095                  DRY  NO DEFECTS  NOT ON SCENE (DESK REPORT)
# 394122                  DRY     UNKNOWN  NOT ON SCENE (DESK REPORT)
# 394573                  DRY  NO DEFECTS                    ON SCENE
# 394587                  WET  NO DEFECTS                    ON SCENE
#
#                         injury/tow_or_no intersection_related  \
# 35                NO INJURY / DRIVE AWAY                  NaN
# 13255             NO INJURY / DRIVE AWAY                  NaN
# 17814             NO INJURY / DRIVE AWAY                  NaN
# 32501             NO INJURY / DRIVE AWAY                  NaN
# 37193             NO INJURY / DRIVE AWAY                  NaN
# ...                                  ...                  ...
# 393955            NO INJURY / DRIVE AWAY                  NaN
# 394095            NO INJURY / DRIVE AWAY                  NaN
# 394122            NO INJURY / DRIVE AWAY                  NaN
# 394573  INJURY AND / OR TOW DUE TO CRASH                  NaN
# 394587            NO INJURY / DRIVE AWAY                  NaN
#
#        not_right_of_way hit_and_run         damage    date_police_notified  \
# 35                  NaN         NaN    OVER $1,500  10/02/2018 07:35:00 PM
# 13255               NaN           Y  $501 - $1,500  11/09/2019 02:48:00 PM
# 17814               NaN         NaN    OVER $1,500  09/21/2019 07:17:00 PM
# 32501               NaN         NaN  $501 - $1,500  02/19/2020 10:05:00 AM
# 37193               NaN           Y  $501 - $1,500  03/02/2020 08:07:00 PM
# ...                 ...         ...            ...                     ...
# 393955              NaN         NaN   $500 OR LESS  07/16/2018 03:20:00 PM
# 394095              NaN         NaN  $501 - $1,500  12/18/2019 05:04:00 PM
# 394122              NaN         NaN    OVER $1,500  06/04/2018 04:55:00 PM
# 394573              NaN         NaN   $500 OR LESS  04/25/2019 01:35:00 PM
# 394587              NaN         NaN    OVER $1,500  01/15/2019 09:05:00 PM
#
#                     prim_contributory_cause            sec_contributory_cause  \
# 35                           NOT APPLICABLE                    NOT APPLICABLE
# 13255                        NOT APPLICABLE                    NOT APPLICABLE
# 17814                        NOT APPLICABLE                    NOT APPLICABLE
# 32501         FAILING TO YIELD RIGHT-OF-WAY                    NOT APPLICABLE
# 37193   DRIVING SKILLS/KNOWLEDGE/EXPERIENCE               UNABLE TO DETERMINE
# ...                                     ...                               ...
# 393955                       NOT APPLICABLE                    NOT APPLICABLE
# 394095                FOLLOWING TOO CLOSELY               UNABLE TO DETERMINE
# 394122        FAILING TO YIELD RIGHT-OF-WAY               UNABLE TO DETERMINE
# 394573        FAILING TO YIELD RIGHT-OF-WAY     FAILING TO YIELD RIGHT-OF-WAY
# 394587          IMPROPER OVERTAKING/PASSING  EXCEEDING AUTHORIZED SPEED LIMIT
#
#         street_no street_direction                  street_name  \
# 35            517                W                     OHARE ST
# 13255        3644                S                   OAKLEY AVE
# 17814        4511                N                   RACINE AVE
# 32501           2                W                  TERMINAL ST
# 37193         515                W                     OHARE ST
# ...           ...              ...                          ...
# 393955       4547                S  DR MARTIN LUTHER KING JR SD
# 394095      13000                S                   DREXEL AVE
# 394122       1950                W                LARCHMONT AVE
# 394573          1                W             PARKING LOT C ST
# 394587          3                W                  TERMINAL ST
#
#         beat_of_occurrence dooring work_zone work_zone_type workers_present  \
# 35                  1654.0     NaN       NaN            NaN             NaN
# 13255                912.0     NaN       NaN            NaN             NaN
# 17814               1913.0     NaN       NaN            NaN             NaN
# 32501               1652.0     NaN       NaN            NaN             NaN
# 37193               1654.0     NaN       NaN            NaN             NaN
# ...                    ...     ...       ...            ...             ...
# 393955               221.0     NaN       NaN            NaN             NaN
# 394095               533.0     NaN       NaN            NaN             NaN
# 394122              1922.0     NaN       NaN            NaN             NaN
# 394573              1654.0     NaN         Y   CONSTRUCTION               N
# 394587              1653.0     NaN       NaN            NaN             NaN
#
#         num_units         most_severenjury  injuries_total  injuries_fatal  \
# 35            2.0  NO INDICATION OF INJURY             0.0             0.0
# 13255         2.0  NO INDICATION OF INJURY             0.0             0.0
# 17814         1.0  NO INDICATION OF INJURY             0.0             0.0
# 32501         2.0  NO INDICATION OF INJURY             0.0             0.0
# 37193         2.0  NO INDICATION OF INJURY             0.0             0.0
# ...           ...                      ...             ...             ...
# 393955        2.0  NO INDICATION OF INJURY             0.0             0.0
# 394095        2.0  NO INDICATION OF INJURY             0.0             0.0
# 394122        2.0  NO INDICATION OF INJURY             0.0             0.0
# 394573        2.0    REPORTED, NOT EVIDENT             1.0             0.0
# 394587        2.0  NO INDICATION OF INJURY             0.0             0.0
#
#         injuriesncapacitating  injuries_nonncapacitating  \
# 35                        0.0                        0.0
# 13255                     0.0                        0.0
# 17814                     0.0                        0.0
# 32501                     0.0                        0.0
# 37193                     0.0                        0.0
# ...                       ...                        ...
# 393955                    0.0                        0.0
# 394095                    0.0                        0.0
# 394122                    0.0                        0.0
# 394573                    0.0                        0.0
# 394587                    0.0                        0.0
#
#         injuries_reported_not_evident  injuries_nondication  crash_hour  \
# 35                                0.0                   1.0          18
# 13255                             0.0                   1.0           1
# 17814                             0.0                   1.0          19
# 32501                             0.0                   2.0          10
# 37193                             0.0                   1.0          20
# ...                               ...                   ...         ...
# 393955                            0.0                  10.0          15
# 394095                            0.0                   2.0          16
# 394122                            0.0                   3.0          16
# 394573                            1.0                   1.0          13
# 394587                            0.0                   2.0          21
#
#         crash_day_of_week  crash_month  latitude  longitude
# 35                      3           10       NaN        NaN
# 13255                   6           11       NaN        NaN
# 17814                   7            9       NaN        NaN
# 32501                   4            2       NaN        NaN
# 37193                   2            3       NaN        NaN
# ...                   ...          ...       ...        ...
# 393955                  2            7       NaN        NaN
# 394095                  4           12       NaN        NaN
# 394122                  2            6       NaN        NaN
# 394573                  5            4       NaN        NaN
# 394587                  3            1       NaN        NaN
#
# [1521 rows x 41 columns]

# %% [markdown]
# if street_no and street_name are the same use that latitude long and location
#
# 517	W	OHARE ST	1654.0

# %%
df1.loc[(df1['street_no'] == 517)& (df1['street_name'] == "OHARE ST")]
# Out:
#                     crash_date  posted_speed_limit traffic_control_device  \
# 35      10/02/2018 06:30:00 PM                  10            NO CONTROLS
# 58843   01/10/2020 04:00:00 PM                  15            NO CONTROLS
# 152720  09/19/2019 04:00:00 PM                  15            NO CONTROLS
# 155904  10/29/2018 09:45:00 PM                  15            NO CONTROLS
# 228429  01/27/2020 02:25:00 PM                  20            NO CONTROLS
# 291554  09/23/2019 09:05:00 PM                  15            NO CONTROLS
#
#        device_condition weather_condition      lighting_condition  \
# 35          NO CONTROLS             CLEAR                DARKNESS
# 58843       NO CONTROLS   CLOUDY/OVERCAST                    DUSK
# 152720      NO CONTROLS             CLEAR                DAYLIGHT
# 155904      NO CONTROLS             CLEAR  DARKNESS, LIGHTED ROAD
# 228429      NO CONTROLS             CLEAR                DAYLIGHT
# 291554      NO CONTROLS             CLEAR  DARKNESS, LIGHTED ROAD
#
#                   crash_type                  trafficway_type  \
# 35      PARKED MOTOR VEHICLE                            OTHER
# 58843           OTHER OBJECT                            OTHER
# 152720  PARKED MOTOR VEHICLE                            OTHER
# 155904  PARKED MOTOR VEHICLE                         DRIVEWAY
# 228429         REAR TO FRONT  DIVIDED - W/MEDIAN (NOT RAISED)
# 291554  PARKED MOTOR VEHICLE                      PARKING LOT
#
#                  alignment roadway_surface_cond road_defect report_type  \
# 35      STRAIGHT AND LEVEL                  DRY  NO DEFECTS    ON SCENE
# 58843   STRAIGHT AND LEVEL                  DRY  NO DEFECTS    ON SCENE
# 152720  STRAIGHT AND LEVEL                  DRY  NO DEFECTS    ON SCENE
# 155904  STRAIGHT AND LEVEL                  DRY  NO DEFECTS    ON SCENE
# 228429  STRAIGHT AND LEVEL                  DRY  NO DEFECTS    ON SCENE
# 291554  STRAIGHT AND LEVEL                  DRY  NO DEFECTS    ON SCENE
#
#               injury/tow_or_no intersection_related not_right_of_way  \
# 35      NO INJURY / DRIVE AWAY                  NaN              NaN
# 58843   NO INJURY / DRIVE AWAY                  NaN              NaN
# 152720  NO INJURY / DRIVE AWAY                  NaN              NaN
# 155904  NO INJURY / DRIVE AWAY                  NaN              NaN
# 228429  NO INJURY / DRIVE AWAY                  NaN              NaN
# 291554  NO INJURY / DRIVE AWAY                  NaN              NaN
#
#        hit_and_run         damage    date_police_notified  \
# 35             NaN    OVER $1,500  10/02/2018 07:35:00 PM
# 58843          NaN  $501 - $1,500  01/10/2020 04:01:00 PM
# 152720         NaN  $501 - $1,500  09/19/2019 04:08:00 PM
# 155904           Y  $501 - $1,500  10/29/2018 09:53:00 PM
# 228429         NaN    OVER $1,500  01/27/2020 02:30:00 PM
# 291554         NaN    OVER $1,500  09/23/2019 09:10:00 PM
#
#                                   prim_contributory_cause  \
# 35                                         NOT APPLICABLE
# 58843                                      NOT APPLICABLE
# 152720  VISION OBSCURED (SIGNS, TREE LIMBS, BUILDINGS,...
# 155904                DRIVING SKILLS/KNOWLEDGE/EXPERIENCE
# 228429                                   IMPROPER BACKING
# 291554                DRIVING SKILLS/KNOWLEDGE/EXPERIENCE
#
#        sec_contributory_cause  street_no street_direction street_name  \
# 35             NOT APPLICABLE        517                W    OHARE ST
# 58843          NOT APPLICABLE        517                W    OHARE ST
# 152720         NOT APPLICABLE        517                W    OHARE ST
# 155904    UNABLE TO DETERMINE        517                W    OHARE ST
# 228429    UNABLE TO DETERMINE        517                W    OHARE ST
# 291554    UNABLE TO DETERMINE        517                W    OHARE ST
#
#         beat_of_occurrence dooring work_zone work_zone_type workers_present  \
# 35                  1654.0     NaN       NaN            NaN             NaN
# 58843               1654.0     NaN       NaN            NaN             NaN
# 152720              1654.0     NaN       NaN            NaN             NaN
# 155904              1654.0     NaN       NaN            NaN             NaN
# 228429              1654.0     NaN       NaN            NaN             NaN
# 291554              1654.0     NaN       NaN            NaN             NaN
#
#         num_units         most_severenjury  injuries_total  injuries_fatal  \
# 35            2.0  NO INDICATION OF INJURY             0.0             0.0
# 58843         1.0  NO INDICATION OF INJURY             0.0             0.0
# 152720        2.0  NO INDICATION OF INJURY             0.0             0.0
# 155904        2.0  NO INDICATION OF INJURY             0.0             0.0
# 228429        2.0  NO INDICATION OF INJURY             0.0             0.0
# 291554        2.0  NO INDICATION OF INJURY             0.0             0.0
#
#         injuriesncapacitating  injuries_nonncapacitating  \
# 35                        0.0                        0.0
# 58843                     0.0                        0.0
# 152720                    0.0                        0.0
# 155904                    0.0                        0.0
# 228429                    0.0                        0.0
# 291554                    0.0                        0.0
#
#         injuries_reported_not_evident  injuries_nondication  crash_hour  \
# 35                                0.0                   1.0          18
# 58843                             0.0                   1.0          16
# 152720                            0.0                   1.0          16
# 155904                            0.0                   1.0          21
# 228429                            0.0                   2.0          14
# 291554                            0.0                   1.0          21
#
#         crash_day_of_week  crash_month  latitude  longitude
# 35                      3           10       NaN        NaN
# 58843                   6            1       NaN        NaN
# 152720                  5            9       NaN        NaN
# 155904                  2           10       NaN        NaN
# 228429                  2            1       NaN        NaN
# 291554                  2            9       NaN        NaN

# %%
df1.loc[(df1['street_no'] == 4547)& (df1['street_name'] == "DR MARTIN LUTHER KING JR SD")]
# Out:
#                     crash_date  posted_speed_limit traffic_control_device  \
# 393955  07/16/2018 03:09:00 PM                  30            NO CONTROLS
#
#        device_condition weather_condition lighting_condition  \
# 393955      NO CONTROLS             CLEAR           DAYLIGHT
#
#                   crash_type trafficway_type           alignment  \
# 393955  PARKED MOTOR VEHICLE         ONE-WAY  STRAIGHT AND LEVEL
#
#        roadway_surface_cond road_defect report_type        injury/tow_or_no  \
# 393955                  DRY  NO DEFECTS    ON SCENE  NO INJURY / DRIVE AWAY
#
#        intersection_related not_right_of_way hit_and_run        damage  \
# 393955                  NaN              NaN         NaN  $500 OR LESS
#
#           date_police_notified prim_contributory_cause sec_contributory_cause  \
# 393955  07/16/2018 03:20:00 PM          NOT APPLICABLE         NOT APPLICABLE
#
#         street_no street_direction                  street_name  \
# 393955       4547                S  DR MARTIN LUTHER KING JR SD
#
#         beat_of_occurrence dooring work_zone work_zone_type workers_present  \
# 393955               221.0     NaN       NaN            NaN             NaN
#
#         num_units         most_severenjury  injuries_total  injuries_fatal  \
# 393955        2.0  NO INDICATION OF INJURY             0.0             0.0
#
#         injuriesncapacitating  injuries_nonncapacitating  \
# 393955                    0.0                        0.0
#
#         injuries_reported_not_evident  injuries_nondication  crash_hour  \
# 393955                            0.0                  10.0          15
#
#         crash_day_of_week  crash_month  latitude  longitude
# 393955                  2            7       NaN        NaN

# %% [markdown]
#     Okay, so we decided to fill in and drop a few columns

# %%
df1['work_zone_type'].fillna("Not work zone", inplace=True)
df1['work_zone'].fillna("N", inplace=True)
df1['workers_present'].fillna("N", inplace=True)
df1.dooring.fillna("N", inplace=True)
df1['intersection_related'].fillna("N", inplace=True)
df1['not_right_of_way'].fillna("N", inplace=True)
df1['hit_and_run'].fillna("N", inplace=True)
df1= df1.dropna(subset=['report_type', 'latitude','most_severenjury', 'beat_of_occurrence'])

# %%
not_determined_df['work_zone_type'].fillna("Not work zone", inplace=True)
not_determined_df['work_zone'].fillna("N", inplace=True)
not_determined_df['workers_present'].fillna("N", inplace=True)
not_determined_df.dooring.fillna("N", inplace=True)
not_determined_df['intersection_related'].fillna("N", inplace=True)
not_determined_df['not_right_of_way'].fillna("N", inplace=True)
not_determined_df['hit_and_run'].fillna("N", inplace=True)
not_determined_df= not_determined_df.dropna(subset=['report_type', 'latitude','most_severenjury', 'beat_of_occurrence'])

# %%
df1.isna().sum()
# Out:
# crash_date                       0
# posted_speed_limit               0
# traffic_control_device           0
# device_condition                 0
# weather_condition                0
# lighting_condition               0
# crash_type                       0
# trafficway_type                  0
# alignment                        0
# roadway_surface_cond             0
# road_defect                      0
# report_type                      0
# injury/tow_or_no                 0
# intersection_related             0
# not_right_of_way                 0
# hit_and_run                      0
# damage                           0
# date_police_notified             0
# prim_contributory_cause          0
# sec_contributory_cause           0
# street_no                        0
# street_direction                 0
# street_name                      0
# beat_of_occurrence               0
# dooring                          0
# work_zone                        0
# work_zone_type                   0
# workers_present                  0
# num_units                        0
# most_severenjury                 0
# injuries_total                   0
# injuries_fatal                   0
# injuriesncapacitating            0
# injuries_nonncapacitating        0
# injuries_reported_not_evident    0
# injuries_nondication             0
# crash_hour                       0
# crash_day_of_week                0
# crash_month                      0
# latitude                         0
# longitude                        0
# year                             0
# dtype: int64

# %%
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 243583 entries, 0 to 395203
# Data columns (total 41 columns):
# crash_date                       243583 non-null object
# posted_speed_limit               243583 non-null int64
# traffic_control_device           243583 non-null object
# device_condition                 243583 non-null object
# weather_condition                243583 non-null object
# lighting_condition               243583 non-null object
# crash_type                       243583 non-null object
# trafficway_type                  243583 non-null object
# alignment                        243583 non-null object
# roadway_surface_cond             243583 non-null object
# road_defect                      243583 non-null object
# report_type                      243583 non-null object
# injury/tow_or_no                 243583 non-null object
# intersection_related             243583 non-null object
# not_right_of_way                 243583 non-null object
# hit_and_run                      243583 non-null object
# damage                           243583 non-null object
# date_police_notified             243583 non-null object
# prim_contributory_cause          243583 non-null object
# sec_contributory_cause           243583 non-null object
# street_no                        243583 non-null int64
# street_direction                 243583 non-null object
# street_name                      243583 non-null object
# beat_of_occurrence               243583 non-null float64
# dooring                          243583 non-null object
# work_zone                        243583 non-null object
# work_zone_type                   243583 non-null object
# workers_present                  243583 non-null object
# num_units                        243583 non-null float64
# most_severenjury                 243583 non-null object
# injuries_total                   243583 non-null float64
# injuries_fatal                   243583 non-null float64
# injuriesncapacitating            243583 non-null float64
# injuries_nonncapacitating        243583 non-null float64
# injuries_reported_not_evident    243583 non-null float64
# injuries_nondication             243583 non-null float64
# crash_hour                       243583 non-null int64
# crash_day_of_week                243583 non-null int64
# crash_month                      243583 non-null int64
# latitude                         243583 non-null float64
# longitude                        243583 non-null float64
# dtypes: float64(10), int64(5), object(26)
# memory usage: 78.1+ MB

# %% [markdown]
# ## Look into Place holders (questions in here!!!)

# %%
for col in df1.columns:
    print(col,'\n', df1[col].value_counts(dropna=False), "\n\n")
# Out:
# crash_date
#  2017-11-10 10:30:00    17
# 2019-01-12 14:00:00    13
# 2017-11-10 10:00:00    12
# 2020-02-26 08:00:00    12
# 2019-01-12 15:00:00    11
#                        ..
# 2017-01-11 19:00:00     1
# 2020-02-18 11:49:00     1
# 2019-11-15 19:30:00     1
# 2017-10-10 19:40:00     1
# 2017-12-31 22:00:00     1
# Name: crash_date, Length: 160280, dtype: int64
#
#
# posted_speed_limit
#  30    155748
# 35     15010
# 25     11251
# 20      6521
# 15      6250
# 10      2989
# 0       2912
# 40      2287
# 5       1466
# 45      1396
# 55       161
# 3         52
# 50        39
# 9         38
# 39        20
# 2         12
# 60        10
# 99         7
# 32         5
# 1          5
# 11         4
# 70         2
# 65         2
# 7          2
# 6          2
# 33         2
# 34         2
# 22         1
# 24         1
# 12         1
# 4          1
# 38         1
# 63         1
# Name: posted_speed_limit, dtype: int64
#
#
# traffic_control_device
#  NO CONTROLS                 112394
# TRAFFIC SIGNAL               66601
# STOP SIGN/FLASHER            23707
# OTHER                         1218
# LANE USE MARKING               825
# YIELD                          340
# OTHER REG. SIGN                268
# OTHER WARNING SIGN             246
# RAILROAD CROSSING GATE         169
# POLICE/FLAGMAN                  95
# PEDESTRIAN CROSSING SIGN        88
# SCHOOL ZONE                     87
# OTHER RAILROAD CROSSING         58
# DELINEATORS                     47
# FLASHING CONTROL SIGNAL         39
# NO PASSING                       9
# RR CROSSING SIGN                 6
# BICYCLE CROSSING SIGN            4
# Name: traffic_control_device, dtype: int64
#
#
# device_condition
#  NO CONTROLS                 115349
# FUNCTIONING PROPERLY         86949
# OTHER                         1572
# FUNCTIONING IMPROPERLY        1422
# NOT FUNCTIONING                743
# WORN REFLECTIVE MATERIAL       127
# MISSING                         39
# Name: device_condition, dtype: int64
#
#
# weather_condition
#  CLEAR                     168955
# RAIN                       20177
# SNOW                        8553
# CLOUDY/OVERCAST             6789
# OTHER                        660
# FOG/SMOKE/HAZE               426
# SLEET/HAIL                   382
# FREEZING RAIN/DRIZZLE        187
# SEVERE CROSS WIND GATE        41
# BLOWING SNOW                  31
# Name: weather_condition, dtype: int64
#
#
# lighting_condition
#  DAYLIGHT                  141818
# DARKNESS, LIGHTED ROAD     44717
# DARKNESS                    8939
# DUSK                        6869
# DAWN                        3858
# Name: lighting_condition, dtype: int64
#
#
# crash_type
#  REAR END                        56441
# SIDESWIPE SAME DIRECTION        34462
# TURNING                         34324
# PARKED MOTOR VEHICLE            29985
# ANGLE                           24933
# FIXED OBJECT                     8661
# PEDESTRIAN                       4965
# PEDALCYCLIST                     3068
# SIDESWIPE OPPOSITE DIRECTION     2984
# HEAD ON                          1961
# OTHER OBJECT                     1841
# REAR TO FRONT                     831
# OTHER NONCOLLISION                809
# REAR TO SIDE                      491
# REAR TO REAR                      173
# ANIMAL                            161
# OVERTURNED                         97
# TRAIN                              14
# Name: crash_type, dtype: int64
#
#
# trafficway_type
#  NOT DIVIDED                        94808
# DIVIDED - W/MEDIAN (NOT RAISED)    41566
# ONE-WAY                            23943
# DIVIDED - W/MEDIAN BARRIER         14756
# PARKING LOT                        12084
# OTHER                               6159
# FOUR WAY                            4657
# ALLEY                               2952
# CENTER TURN LANE                    2176
# T-INTERSECTION                      1009
# RAMP                                 731
# DRIVEWAY                             715
# UNKNOWN INTERSECTION TYPE            232
# Y-INTERSECTION                       121
# FIVE POINT, OR MORE                  109
# TRAFFIC ROUTE                         99
# NOT REPORTED                          38
# ROUNDABOUT                            28
# L-INTERSECTION                        18
# Name: trafficway_type, dtype: int64
#
#
# alignment
#  STRAIGHT AND LEVEL       200323
# STRAIGHT ON GRADE          2814
# CURVE, LEVEL               1787
# STRAIGHT ON HILLCREST       812
# CURVE ON GRADE              344
# CURVE ON HILLCREST          121
# Name: alignment, dtype: int64
#
#
# roadway_surface_cond
#  DRY                164069
# WET                 31616
# SNOW OR SLUSH        7927
# ICE                  2021
# OTHER                 456
# SAND, MUD, DIRT       112
# Name: roadway_surface_cond, dtype: int64
#
#
# road_defect
#  NO DEFECTS           200562
# RUT, HOLES             2479
# OTHER                  1424
# WORN SURFACE            955
# SHOULDER DEFECT         550
# DEBRIS ON ROADWAY       231
# Name: road_defect, dtype: int64
#
#
# report_type
#  NOT ON SCENE (DESK REPORT)    112359
# ON SCENE                       93842
# Name: report_type, dtype: int64
#
#
# injury/tow_or_no
#  NO INJURY / DRIVE AWAY              149484
# INJURY AND / OR TOW DUE TO CRASH     56717
# Name: injury/tow_or_no, dtype: int64
#
#
# intersection_related
#  N    153610
# Y     52591
# Name: intersection_related, dtype: int64
#
#
# not_right_of_way
#  N    198045
# Y      8156
# Name: not_right_of_way, dtype: int64
#
#
# hit_and_run
#  N    165906
# Y     40295
# Name: hit_and_run, dtype: int64
#
#
# damage
#  OVER $1,500      121779
# $501 - $1,500     57473
# $500 OR LESS      26949
# Name: damage, dtype: int64
#
#
# date_police_notified
#  02/26/2020 08:30:00 AM    8
# 05/30/2019 05:00:00 PM    8
# 12/12/2017 05:30:00 PM    7
# 12/11/2017 06:00:00 PM    7
# 01/12/2019 04:30:00 PM    7
#                          ..
# 09/18/2019 12:25:00 PM    1
# 02/16/2017 08:53:00 PM    1
# 11/15/2019 10:02:00 AM    1
# 01/12/2018 11:32:00 PM    1
# 10/12/2019 05:46:00 AM    1
# Name: date_police_notified, Length: 178253, dtype: int64
#
#
# prim_contributory_cause
#  FAILING TO YIELD RIGHT-OF-WAY                                                       37461
# FOLLOWING TOO CLOSELY                                                               36266
# NOT APPLICABLE                                                                      16011
# IMPROPER OVERTAKING/PASSING                                                         15418
# IMPROPER BACKING                                                                    14405
# FAILING TO REDUCE SPEED TO AVOID CRASH                                              13516
# IMPROPER LANE USAGE                                                                 13344
# IMPROPER TURNING/NO SIGNAL                                                          11124
# DRIVING SKILLS/KNOWLEDGE/EXPERIENCE                                                  9572
# DISREGARDING TRAFFIC SIGNALS                                                         5429
# WEATHER                                                                              5260
# OPERATING VEHICLE IN ERRATIC, RECKLESS, CARELESS, NEGLIGENT OR AGGRESSIVE MANNER     3749
# DISREGARDING STOP SIGN                                                               3384
# DISTRACTION - FROM INSIDE VEHICLE                                                    2451
# VISION OBSCURED (SIGNS, TREE LIMBS, BUILDINGS, ETC.)                                 1992
# EQUIPMENT - VEHICLE CONDITION                                                        1926
# PHYSICAL CONDITION OF DRIVER                                                         1898
# UNDER THE INFLUENCE OF ALCOHOL/DRUGS (USE WHEN ARREST IS EFFECTED)                   1651
# EXCEEDING AUTHORIZED SPEED LIMIT                                                     1603
# EXCEEDING SAFE SPEED FOR CONDITIONS                                                  1421
# DISTRACTION - FROM OUTSIDE VEHICLE                                                   1418
# DRIVING ON WRONG SIDE/WRONG WAY                                                      1360
# ROAD ENGINEERING/SURFACE/MARKING DEFECTS                                             1040
# ROAD CONSTRUCTION/MAINTENANCE                                                         837
# DISREGARDING OTHER TRAFFIC SIGNS                                                      674
# EVASIVE ACTION DUE TO ANIMAL, OBJECT, NONMOTORIST                                     586
# DISREGARDING ROAD MARKINGS                                                            480
# CELL PHONE USE OTHER THAN TEXTING                                                     459
# HAD BEEN DRINKING (USE WHEN ARREST IS NOT MADE)                                       344
# ANIMAL                                                                                266
# TURNING RIGHT ON RED                                                                  217
# DISTRACTION - OTHER ELECTRONIC DEVICE (NAVIGATION DEVICE, DVD PLAYER, ETC.)           165
# TEXTING                                                                               152
# DISREGARDING YIELD SIGN                                                               111
# RELATED TO BUS STOP                                                                    85
# BICYCLE ADVANCING LEGALLY ON RED LIGHT                                                 52
# PASSING STOPPED SCHOOL BUS                                                             46
# OBSTRUCTED CROSSWALKS                                                                  18
# MOTORCYCLE ADVANCING LEGALLY ON RED LIGHT                                              10
# Name: prim_contributory_cause, dtype: int64
#
#
# sec_contributory_cause
#  NOT APPLICABLE                                                                      87496
# UNABLE TO DETERMINE                                                                 42112
# FAILING TO REDUCE SPEED TO AVOID CRASH                                              14164
# DRIVING SKILLS/KNOWLEDGE/EXPERIENCE                                                 10046
# FAILING TO YIELD RIGHT-OF-WAY                                                        9977
# FOLLOWING TOO CLOSELY                                                                8638
# IMPROPER LANE USAGE                                                                  4650
# IMPROPER OVERTAKING/PASSING                                                          4367
# WEATHER                                                                              3911
# IMPROPER TURNING/NO SIGNAL                                                           3320
# IMPROPER BACKING                                                                     2596
# OPERATING VEHICLE IN ERRATIC, RECKLESS, CARELESS, NEGLIGENT OR AGGRESSIVE MANNER     2055
# EXCEEDING SAFE SPEED FOR CONDITIONS                                                  1198
# DISREGARDING TRAFFIC SIGNALS                                                         1193
# VISION OBSCURED (SIGNS, TREE LIMBS, BUILDINGS, ETC.)                                 1186
# EXCEEDING AUTHORIZED SPEED LIMIT                                                     1170
# DISTRACTION - FROM INSIDE VEHICLE                                                    1070
# DISREGARDING STOP SIGN                                                                935
# PHYSICAL CONDITION OF DRIVER                                                          865
# EQUIPMENT - VEHICLE CONDITION                                                         618
# DISTRACTION - FROM OUTSIDE VEHICLE                                                    580
# DRIVING ON WRONG SIDE/WRONG WAY                                                       522
# UNDER THE INFLUENCE OF ALCOHOL/DRUGS (USE WHEN ARREST IS EFFECTED)                    513
# ROAD CONSTRUCTION/MAINTENANCE                                                         406
# ROAD ENGINEERING/SURFACE/MARKING DEFECTS                                              394
# DISREGARDING ROAD MARKINGS                                                            370
# DISREGARDING OTHER TRAFFIC SIGNS                                                      314
# HAD BEEN DRINKING (USE WHEN ARREST IS NOT MADE)                                       291
# CELL PHONE USE OTHER THAN TEXTING                                                     280
# EVASIVE ACTION DUE TO ANIMAL, OBJECT, NONMOTORIST                                     176
# BICYCLE ADVANCING LEGALLY ON RED LIGHT                                                130
# TURNING RIGHT ON RED                                                                  120
# ANIMAL                                                                                114
# DISTRACTION - OTHER ELECTRONIC DEVICE (NAVIGATION DEVICE, DVD PLAYER, ETC.)           109
# RELATED TO BUS STOP                                                                    83
# DISREGARDING YIELD SIGN                                                                82
# TEXTING                                                                                60
# PASSING STOPPED SCHOOL BUS                                                             44
# MOTORCYCLE ADVANCING LEGALLY ON RED LIGHT                                              25
# OBSTRUCTED CROSSWALKS                                                                  21
# Name: sec_contributory_cause, dtype: int64
#
#
# street_no
#  100      1570
# 1600     1390
# 200      1330
# 800      1282
# 300      1275
#          ...
# 11937       1
# 11809       1
# 10976       1
# 7463        1
# 7612        1
# Name: street_no, Length: 9660, dtype: int64
#
#
# street_direction
#  W    73680
# S    67731
# N    50539
# E    14251
# Name: street_direction, dtype: int64
#
#
# street_name
#  WESTERN AVE        5949
# PULASKI RD         5297
# CICERO AVE         4836
# ASHLAND AVE        4572
# HALSTED ST         4096
#                    ...
# LA SALLE              1
# EAST CIRCLE AVE       1
# BONAPARTE ST          1
# GOVERNORS PKWY        1
# ELSTON PKWY           1
# Name: street_name, Length: 1383, dtype: int64
# beat_of_occurrence
#  1834.0    3094
# 114.0     2870
# 122.0     2690
# 1831.0    2305
# 813.0     2242
#           ...
# 231.0      224
# 232.0      216
# 422.0      169
# 1125.0     162
# 1654.0     141
# Name: beat_of_occurrence, Length: 271, dtype: int64
#
#
# dooring
#  N    205789
# Y       412
# Name: dooring, dtype: int64
#
#
# work_zone
#  N    204985
# Y      1216
# Name: work_zone, dtype: int64
#
#
# work_zone_type
#  Not work zone    204985
# CONSTRUCTION        964
# MAINTENANCE         157
# UTILITY              95
# Name: work_zone_type, dtype: int64
#
#
# workers_present
#  N    205836
# Y       365
# Name: workers_present, dtype: int64
#
#
# num_units
#  2.0     181792
# 3.0      11162
# 1.0      10651
# 4.0       1945
# 5.0        451
# 6.0        118
# 7.0         43
# 8.0         18
# 9.0          8
# 10.0         7
# 12.0         2
# 11.0         2
# 15.0         1
# 18.0         1
# Name: num_units, dtype: int64
#
#
# most_severenjury
#  NO INDICATION OF INJURY     176339
# NONINCAPACITATING INJURY     16536
# REPORTED, NOT EVIDENT         9367
# INCAPACITATING INJURY         3795
# FATAL                          164
# Name: most_severenjury, dtype: int64
#
#
# injuries_total
#  0.0     176339
# 1.0      22569
# 2.0       4915
# 3.0       1484
# 4.0        532
# 5.0        217
# 6.0         79
# 7.0         32
# 8.0         11
# 9.0         11
# 10.0         5
# 11.0         4
# 13.0         1
# 21.0         1
# 19.0         1
# Name: injuries_total, dtype: int64
#
#
# injuries_fatal
#  0.0    206037
# 1.0       152
# 2.0         8
# 3.0         4
# Name: injuries_fatal, dtype: int64
#
#
# injuriesncapacitating
#  0.0    202382
# 1.0      3312
# 2.0       369
# 3.0        97
# 4.0        34
# 5.0         5
# 7.0         1
# 6.0         1
# Name: injuriesncapacitating, dtype: int64
#
#
# injuries_nonncapacitating
#  0.0     188952
# 1.0      13654
# 2.0       2470
# 3.0        701
# 4.0        267
# 5.0         90
# 6.0         36
# 7.0         17
# 8.0          4
# 11.0         3
# 10.0         3
# 9.0          2
# 21.0         1
# 18.0         1
# Name: injuries_nonncapacitating, dtype: int64
#
#
# injuries_reported_not_evident
#  0.0     195701
# 1.0       8303
# 2.0       1557
# 3.0        421
# 4.0        132
# 5.0         60
# 6.0         14
# 7.0          4
# 8.0          4
# 9.0          3
# 10.0         2
# Name: injuries_reported_not_evident, dtype: int64
#
#
# injuries_nondication
#  2.0     107194
# 1.0      46622
# 3.0      29032
# 4.0      11031
# 5.0       4710
# 0.0       4047
# 6.0       2058
# 7.0        775
# 8.0        339
# 9.0        149
# 10.0        84
# 11.0        34
# 12.0        27
# 14.0        18
# 13.0        13
# 16.0        10
# 17.0         8
# 15.0         6
# 20.0         6
# 21.0         5
# 27.0         4
# 37.0         4
# 26.0         3
# 22.0         2
# 30.0         2
# 18.0         2
# 19.0         2
# 42.0         2
# 40.0         2
# 45.0         1
# 31.0         1
# 25.0         1
# 36.0         1
# 34.0         1
# 29.0         1
# 61.0         1
# 38.0         1
# 39.0         1
# 28.0         1
# Name: injuries_nondication, dtype: int64
#
#
# crash_hour
#  16    16077
# 17    15933
# 15    15701
# 14    13582
# 8     12870
# 18    12776
# 13    12318
# 12    11820
# 11    11001
# 9     10543
# 7     10345
# 10    10027
# 19     9108
# 20     7014
# 21     6064
# 22     5683
# 6      4922
# 23     4705
# 0      3489
# 1      2904
# 2      2600
# 5      2538
# 3      2183
# 4      1998
# Name: crash_hour, dtype: int64
#
#
# crash_day_of_week
#  6    34231
# 5    30369
# 3    30063
# 4    29959
# 7    29550
# 2    28598
# 1    23431
# Name: crash_day_of_week, dtype: int64
#
#
# crash_month
#  10    20248
# 12    19302
# 11    18949
# 9     18392
# 1     17724
# 8     17216
# 2     16774
# 3     16136
# 5     15878
# 7     15863
# 6     15575
# 4     14144
# Name: crash_month, dtype: int64
#
#
# latitude
#  41.976201    309
# 41.791420    140
# 41.751461    125
# 41.900959    116
# 41.722257    104
#             ...
# 41.922948      1
# 41.857918      1
# 42.000888      1
# 41.865049      1
# 41.967570      1
# Name: latitude, Length: 108887, dtype: int64
#
#
# longitude
#  -87.905309    309
# -87.580148    140
# -87.585972    125
# -87.619928    116
# -87.585276    104
#              ...
# -87.694210      1
# -87.727661      1
# -87.729869      1
# -87.600951      1
# -87.575590      1
# Name: longitude, Length: 108878, dtype: int64
#
#
# year
#  2018    64133
# 2019    59953
# 2017    44464
# 2016    21674
# 2020    10922
# 2015     5053
# 2014        1
# 2013        1
# Name: year, dtype: int64

# %% [markdown]
# posted_speed_limit
#     - why is there 99 or 70 or 4?
#     - Posted speed limit, as determined by reporting office
#     - WHAT THE HELL DO I DO WITH OTHER OR UNKNOW???
#
# sec_contributory_cause
#     - What do i do with not applicable and unable to determine?
#
#
# - if a column is Y or N - can i just keep it like that? no dummifying right?

# %% [markdown]
# ## Data type

# %%
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 206201 entries, 0 to 395203
# Data columns (total 42 columns):
# crash_date                       206201 non-null datetime64[ns]
# posted_speed_limit               206201 non-null int64
# traffic_control_device           206201 non-null object
# device_condition                 206201 non-null object
# weather_condition                206201 non-null object
# lighting_condition               206201 non-null object
# crash_type                       206201 non-null object
# trafficway_type                  206201 non-null object
# alignment                        206201 non-null object
# roadway_surface_cond             206201 non-null object
# road_defect                      206201 non-null object
# report_type                      206201 non-null object
# injury/tow_or_no                 206201 non-null object
# intersection_related             206201 non-null object
# not_right_of_way                 206201 non-null object
# hit_and_run                      206201 non-null object
# damage                           206201 non-null object
# date_police_notified             206201 non-null object
# sec_contributory_cause           206201 non-null object
# street_no                        206201 non-null int64
# street_direction                 206201 non-null object
# street_name                      206201 non-null object
# beat_of_occurrence               206201 non-null float64
# dooring                          206201 non-null object
# work_zone                        206201 non-null object
# work_zone_type                   206201 non-null object
# workers_present                  206201 non-null object
# num_units                        206201 non-null float64
# most_severenjury                 206201 non-null object
# injuries_total                   206201 non-null float64
# injuries_fatal                   206201 non-null float64
# injuriesncapacitating            206201 non-null float64
# injuries_nonncapacitating        206201 non-null float64
# injuries_reported_not_evident    206201 non-null float64
# injuries_nondication             206201 non-null float64
# crash_hour                       206201 non-null int64
# crash_day_of_week                206201 non-null int64
# crash_month                      206201 non-null int64
# latitude                         206201 non-null float64
# longitude                        206201 non-null float64
# year                             206201 non-null int64
# target_names                     206201 non-null object
# dtypes: datetime64[ns](1), float64(10), int64(6), object(25)
# memory usage: 67.6+ MB

# %% [markdown]
# # Saved files

# %%
df1['target_names'] = df1['prim_contributory_cause']
df1.drop('prim_contributory_cause', axis=1, inplace=True)

# %%
df1.to_csv("clean_car_crash.csv", index=False)

# %%
not_determined_df.to_csv("not_determined.csv", index=False)

# %% [markdown]
# Drop
#
# - work_zone_type
# - street_dierction
# - MAYBE sec_contributory_cause
# - MAYBE street_name
# - date_police_notified
#
#
# - road_defect - drop unknown
# - road_surface_condition - drop unknown intersection type
# - trafficway_type - drop unknown
# - lighting_condition - drop unknown
# - weather_condition - drop unknown
# - device consition - drop unknown/missing
# - traffic_control_device - drop unknown

# %% [markdown]
# # Other

# %%
for num in list(range(2,102, 5)):
    print(num)
# Out:
# 2
# 7
# 12
# 17
# 22
# 27
# 32
# 37
# 42
# 47
# 52
# 57
# 62
# 67
# 72
# 77
# 82
# 87
# 92
# 97
